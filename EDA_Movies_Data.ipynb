# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
pd.options.display.max_columns = 30

# %% [markdown]
# ## Data Import and first Inspection
# #### This is big dataset so I'm giving a drive link to download it from
# ##### https://drive.google.com/file/d/1InTz_34_PxvQak7eBmvk5agDhA9Ov501/view?usp=sharing

# %%
movies = pd.read_csv("movies_clean.csv",parse_dates=['release_date'])

# %%
#Looking at the first 5 rows
movies.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
#Finding out the number of rows and columns
movies.shape
#We have 44691 rows and 22 columns
# Out:
# (44691, 22)

# %%
#Looking at the columns of the dataset
movies.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
#Getting some description of the columns
movies.describe(include='all')
# Out:
#                    id       title                 tagline  \
# count    44691.000000       44691                   20284
# unique            NaN       41605                   20171
# top               NaN  Cinderella  Based on a true story.
# freq              NaN          11                       7
# first             NaN         NaN                     NaN
# last              NaN         NaN                     NaN
# mean    107186.242845         NaN                     NaN
# std     111806.362236         NaN                     NaN
# min          2.000000         NaN                     NaN
# 25%      26033.500000         NaN                     NaN
# 50%      59110.000000         NaN                     NaN
# 75%     154251.000000         NaN                     NaN
# max     469172.000000         NaN                     NaN
#
#                release_date genres belongs_to_collection original_language  \
# ...

# %%
movies.info()
#There are many null values, but we wont be bothered by it as pandas can effectively handle them.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
#Plotting the numeric columns
movies.hist(figsize=(20,12),bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EEAA621340>,
# ...
#       dtype=object)

# %%
#In the title column we can see that there are many duplicates.
#Cinderella has 11 rows so we should check if they are real duplicates
movies[movies.title=='Cinderella']
#These are all different movies with the same title, so it is okay.
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
movies.sort_values(by='revenue_musd',ascending=False)[['title','revenue_musd']][0:5]
# Out:
#                               title  revenue_musd
# 14448                        Avatar   2787.965087
# 26265  Star Wars: The Force Awakens   2068.223624
# 1620                        Titanic   1845.034188
# 17669                  The Avengers   1519.557910
# 24812                Jurassic World   1513.528810

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
movies.sort_values(by='budget_musd',ascending=False)[['title','budget_musd']][0:5]
# Out:
#                                              title  budget_musd
# 16986  Pirates of the Caribbean: On Stranger Tides        380.0
# 11743     Pirates of the Caribbean: At World's End        300.0
# 26268                      Avengers: Age of Ultron        280.0
# 10985                             Superman Returns        270.0
# 18517                                  John Carter        260.0

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
#Creating Profit column which is revenue - budget
movies['profit'] = movies['revenue_musd']-movies['budget_musd']

# %%
movies.sort_values(by='profit',ascending=False)[['title','profit']][0:5]
# Out:
#                               title       profit
# 14448                        Avatar  2550.965087
# 26265  Star Wars: The Force Awakens  1823.223624
# 1620                        Titanic  1645.034188
# 24812                Jurassic World  1363.528810
# 28501                     Furious 7  1316.249360

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
movies.sort_values(by='profit',ascending=True)[['title','profit']][0:5]
# Out:
#                                              title      profit
# 20959                              The Lone Ranger -165.710090
# 7164                                     The Alamo -119.180039
# 16659                              Mars Needs Moms -111.007242
# 43611  Valerian and the City of a Thousand Planets -107.447384
# 2684                              The 13th Warrior  -98.301101

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
#Creating ROI column = revenue/budget
movies['ROI'] = movies['revenue_musd']/movies['budget_musd']

# %%
movies.loc[movies['budget_musd']>=10].sort_values(by='ROI',ascending=False)[['title','ROI']][0:5]
# Out:
#                             title        ROI
# 1055   E.T. the Extra-Terrestrial  75.520507
# 255                     Star Wars  70.490728
# 588                  Pretty Woman  33.071429
# 18300            The Intouchables  32.806221
# 1144      The Empire Strikes Back  29.911111

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
movies.loc[movies['budget_musd']>=10].sort_values(by='ROI',ascending=True)[['title','ROI']][0:5]
# Out:
#                  title           ROI
# 6955   Chasing Liberty  5.217391e-07
# 8041       The Cookout  7.500000e-07
# 17381         Deadfall  1.800000e-06
# 6678        In the Cut  1.916667e-06
# 20015    The Samaritan  2.100833e-04

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
movies.sort_values(by='vote_count',ascending=False)[['title','vote_count']][0:5]
# Out:
#                  title  vote_count
# 15368        Inception     14075.0
# 12396  The Dark Knight     12269.0
# 14448           Avatar     12114.0
# 17669     The Avengers     12000.0
# 26272         Deadpool     11444.0

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
movies.loc[movies['vote_count']>=10].sort_values(by='vote_average',ascending=False)[['title','vote_average']][0:5]
# Out:
#                                                    title  vote_average
# 20787  As I Was Moving Ahead Occasionally I Saw Brief...           9.5
# 42626                                    Planet Earth II           9.5
# 18462                                      The Civil War           9.2
# 10233                        Dilwale Dulhania Le Jayenge           9.1
# 42822                                             Cosmos           9.1

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
movies.loc[movies['vote_count']>=10].sort_values(by='vote_average',ascending=True)[['title','vote_average']][0:5]
# Out:
#                                  title  vote_average
# 41602             Call Me by Your Name           0.0
# 30618   Extinction: Nature Has Evolved           0.0
# 43576  How to Talk to Girls at Parties           0.0
# 25418                      Santa Claus           1.6
# 7030          The Beast of Yucca Flats           1.6

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
movies.sort_values(by='popularity',ascending=False)[['title','popularity']][0:5]
# Out:
#                       title  popularity
# 30330               Minions  547.488298
# 32927          Wonder Woman  294.337037
# 41556  Beauty and the Beast  287.253654
# 42940           Baby Driver  228.032744
# 24187            Big Hero 6  213.849907

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
#Search 1
genres = movies.genres.str.contains('Action') & movies.genres.str.contains('Science Fiction')
actor = movies.cast.str.contains('Bruce Willis')
movies.loc[genres & actor, ['title','vote_average']].sort_values(by='vote_average',ascending=False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element           7.3
# 19218                 Looper           6.6
# 1786              Armageddon           6.5
# 14135             Surrogates           5.9
# 20333  G.I. Joe: Retaliation           5.4
# 27619                   Vice           4.1

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
#Search 2
actor =  movies.cast.str.contains('Uma Thurman')
director = movies.director.str.contains('Quentin Tarantino')
movies.loc[director & actor, ['title','runtime']].sort_values(by='runtime',ascending=True)
# Out:
#                   title  runtime
# 6667  Kill Bill: Vol. 1    111.0
# 7208  Kill Bill: Vol. 2    136.0
# 291        Pulp Fiction    154.0

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
#Search 3
date = movies.release_date.between("2010-01-01", "2015-12-31")
studio = movies.production_companies.str.contains('Pixar').fillna(False)
movies.loc[studio&date,['title','revenue_musd']].sort_values(by='revenue_musd',ascending=False)
# Out:
#                             title  revenue_musd
# 15236                 Toy Story 3   1066.969703
# 29957                  Inside Out    857.611174
# 20888         Monsters University    743.559607
# 17220                      Cars 2    559.852396
# 18900                       Brave    538.983207
# 30388           The Good Dinosaur    331.926147
# 16392                 Day & Night           NaN
# 21694           The Blue Umbrella           NaN
# 21697        Toy Story of Terror!           NaN
# 22489                     La luna           NaN
# 24252           Hawaiian Vacation           NaN
# 24254                   Small Fry           NaN
# 25515             Partysaurus Rex           NaN
# 25516        The Legend of Mor'du           NaN
# 25517  Toy Story That Time Forgot           NaN
# 31803                        Lava           NaN
# 34560         Sanjay's Super Team           NaN
# 40259                   Air Mater           NaN
# 40675         Riley's First Date?           NaN

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
#Search 4
genres = movies.genres.str.contains('Action') | movies.genres.str.contains('Thriller')
language = movies['original_language']=='en'
rating = movies['vote_average']>=7.5
movies.loc[genres&language&rating&(movies.vote_count>50),['title','release_date']].sort_values(by='release_date',ascending=False)[0:20]
# Out:
#                                 title release_date
# 44490                   Descendants 2   2017-07-21
# 43941                         Dunkirk   2017-07-19
# 42624               The Book of Henry   2017-06-16
# 26273  Guardians of the Galaxy Vol. 2   2017-04-19
# 41506                           Logan   2017-02-28
# 40525                    The Thinning   2016-10-12
# 37677                        11.22.63   2016-02-15
# 26265    Star Wars: The Force Awakens   2015-12-15
# 32618                       Spotlight   2015-11-06
# 31737                            Room   2015-10-16
# 29709                       Kung Fury   2015-05-22
# 25257    Kingsman: The Secret Service   2015-01-29
# 43940   Black Mirror: White Christmas   2014-12-16
# 24588              The Imitation Game   2014-11-14
# 24187                      Big Hero 6   2014-10-24
# 24177                    Nightcrawler   2014-10-23
# 23419                       Gone Girl   2014-10-01
# ...

# %% [markdown]
# ## What are the most common Words in Movie Titles and Taglines?

# %%
from wordcloud import WordCloud

# %%
#We are basically interested in the title, overview and tegline columns
#But first we have to drop the null values
title = movies.title.dropna()
overview = movies.overview.dropna()
tagline = movies.tagline.dropna()

# %%
#Creating corpus' of these columns
title_corpus = " ".join(title)
overview_corpus = " ".join(overview)
tagline_corpus = " ".join(tagline)

# %%
title_wordcloud = WordCloud(background_color='white',height=2000,width=2000,font_step=2,max_words=100).generate(title_corpus)

# %%
plt.figure(figsize=(12,12))
plt.imshow(title_wordcloud)

# %%
overview_wordcloud = WordCloud(background_color='white',height=2000,width=2000,font_step=2,max_words=100).generate(overview_corpus)

# %%
plt.figure(figsize=(12,12))
plt.imshow(overview_wordcloud)

# %%
tagline_wordcloud = WordCloud(background_color='white',height=2000,width=2000,font_step=2,max_words=100).generate(tagline_corpus)

# %%
plt.figure(figsize=(12,12))
plt.imshow(tagline_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Are Franchises more successful?

# %%
movies['franchise'] = movies.belongs_to_collection.notna()

# %%
movies.franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: franchise, dtype: int64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
movies.groupby('franchise').mean().revenue_musd
#We see that franchise movies have almost 4 times revenue as compared to the non-franchise movies
# Out:
# franchise
# False     44.742814
# True     165.708193
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
movies.groupby('franchise').median().ROI
# Out:
# franchise
# False    1.619699
# True     3.709195
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
movies.groupby('franchise').mean().budget_musd
# Out:
# franchise
# False    18.047741
# True     38.319847
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
movies.groupby('franchise').mean().popularity
# Out:
# franchise
# False    2.592726
# True     6.245051
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
movies.loc[movies['vote_count']>10].groupby('franchise').mean().vote_average
#We can see that rating average is almost equal
# Out:
# franchise
# False    6.219496
# True     6.021316
# Name: vote_average, dtype: float64

# %%
movies.groupby('franchise').agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean",
                            "popularity": "mean", "ROI":"median", "vote_count":"mean"})
#We see difference between franchise and non-franchise movies based on different factors
# Out:
#            budget_musd  revenue_musd  vote_average  popularity       ROI  \
# franchise
# False        18.047741     44.742814      6.008787    2.592726  1.619699
# True         38.319847    165.708193      5.956806    6.245051  3.709195
#
#            vote_count
# franchise
# False       78.289550
# True       412.387856

# %% [markdown]
# ## Most Successful Franchises

# %%
franchises = movies.loc[movies.franchise==True].groupby('belongs_to_collection').agg({"title":"count", "budget_musd": ["sum", "mean"], 
                                                      "revenue_musd": ["sum", "mean"],
                                                      "vote_average": "mean", "popularity": "mean",
                                                      "ROI":"median", 
                                                      "vote_count":"mean"})

# %%
franchises.nlargest(20,('title','count'))
# Out:
#                                        title budget_musd             \
#                                        count         sum       mean
# belongs_to_collection
# The Bowery Boys                           29      0.0000        NaN
# Totò Collection                           27      0.0000        NaN
# James Bond Collection                     26   1539.6500  59.217308
# Zatôichi: The Blind Swordsman             26      0.0000        NaN
# The Carry On Collection                   25      0.0000        NaN
# Charlie Chan (Sidney Toler) Collection    21      0.0000        NaN
# Pokémon Collection                        20    250.7204  50.144080
# Godzilla (Showa) Collection               16      2.8100   0.562000
# Charlie Chan (Warner Oland) Collection    15      0.0000        NaN
# Dragon Ball Z (Movie) Collection          15      5.0000   5.000000
# Uuno Turhapuro                            15      0.0000        NaN
# ...

# %%
franchises.nlargest(20, ("revenue_musd", "mean"))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# Avatar Collection                       1      237.00  237.000000
# The Avengers Collection                 2      500.00  250.000000
# Frozen Collection                       2      150.00  150.000000
# Finding Nemo Collection                 2      294.00  147.000000
# The Hobbit Collection                   3      750.00  250.000000
# The Lord of the Rings Collection        3      266.00   88.666667
# Harry Potter Collection                 8     1280.00  160.000000
# Star Wars Collection                    8      854.35  106.793750
# Despicable Me Collection                6      299.00   74.750000
# Pirates of the Caribbean Collection     5     1250.00  250.000000
# The Secret Life of Pets Collection      1       75.00   75.000000
# Transformers Collection                 5      965.00  193.000000
# ...

# %%
franchises.nlargest(20, ("budget_musd", "mean"))
# Out:
#                                         title budget_musd              \
#                                         count         sum        mean
# belongs_to_collection
# Tangled Collection                          2       260.0  260.000000
# Pirates of the Caribbean Collection         5      1250.0  250.000000
# The Avengers Collection                     2       500.0  250.000000
# The Hobbit Collection                       3       750.0  250.000000
# Man of Steel Collection                     2       475.0  237.500000
# Avatar Collection                           1       237.0  237.000000
# The Amazing Spider-Man Collection           2       415.0  207.500000
# World War Z Collection                      1       200.0  200.000000
# Spider-Man Collection                       3       597.0  199.000000
# The Dark Knight Collection                  3       585.0  195.000000
# Transformers Collection                     5       965.0  193.000000
# ...

# %%
franchises[franchises[("vote_count", "mean")] >=1000].nlargest(20, ("vote_average", "mean"))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00   88.666667
# The Godfather Collection                3       73.00   24.333333
# Blade Runner Collection                 1       28.00   28.000000
# The Man With No Name Collection         3        2.00    0.666667
# The Dark Knight Collection              3      585.00  195.000000
# Guardians of the Galaxy Collection      2      370.00  185.000000
# Kill Bill Collection                    2       60.00   30.000000
# Kingsman Collection                     1       81.00   81.000000
# How to Train Your Dragon Collection     2      310.00  155.000000
# Harry Potter Collection                 8     1280.00  160.000000
# Toy Story Collection                    3      320.00  106.666667
# Back to the Future Collection           3       99.00   33.000000
# ...

# %% [markdown]
# ## Most Successful Directors

# %%
movies.director.value_counts()[0:20].plot(kind='bar')

# %%
movies.groupby('director').sum().revenue_musd.nlargest(20).plot(kind='bar')

# %%
directors = movies.groupby("director").agg({"title": "count", "vote_average" :"mean", "vote_count": "sum"})

# %%
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, "vote_average")
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14      7.700000     14700.0
# Christopher Nolan     11      7.618182     67344.0
# Quentin Tarantino     10      7.490000     45910.0
# Wes Anderson          10      7.370000     11743.0
# David Fincher         10      7.350000     37588.0
# Martin Scorsese       39      7.218421     35541.0
# Peter Jackson         13      7.138462     47571.0
# Joel Coen             17      7.023529     18139.0
# James Cameron         11      6.927273     33736.0
# Stanley Kubrick       16      6.912500     18214.0
# James Mangold         10      6.900000     16607.0
# Steven Spielberg      33      6.893939     62266.0
# Danny Boyle           14      6.871429     16504.0
# Guy Ritchie           10      6.800000     19626.0
# Robert Zemeckis       19      6.794737     37666.0
# Terry Gilliam         14      6.764286     10049.0
# Tim Burton            21      6.733333     36922.0
# ...

# %% [markdown]
# ## Most Successful Actors (Part 1)

# %%
movies.set_index("id",inplace=True)

# %%
act = movies.cast.str.split('|',expand=True)

# %%
act = act.stack().reset_index(level=1,drop=True).to_frame()

# %%
act.columns = ['Actors']

# %%
act = act.merge(movies[["title", "revenue_musd", "vote_average", "popularity"]],how='left',left_index=True,right_index=True)

# %% [markdown]
# ## Most Successful Actors (Part 2)

# %%
act.Actors.nunique()
#There are more than 200K actors
# Out:
# 201501

# %%
#Actors featured in most movies
act.Actors.value_counts().head(20)
# Out:
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# John Carradine        109
# Gérard Depardieu      109
# Donald Sutherland     108
# Jackie Chan           108
# Frank Welker          107
# Robert De Niro        104
# Steve Buscemi         101
# Danny Trejo           101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Dennis Hopper          92
# Susan Sarandon         92
# Name: Actors, dtype: int64

# %%
plt.figure(figsize = (12, 8))
act.Actors.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Actors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
agg = act.groupby("Actors").agg(Total_Revenue = ("revenue_musd", "sum"), 
                               Mean_Revenue = ("revenue_musd", "mean"),
                               Mean_Rating = ("vote_average", "mean"), 
                               Mean_Pop = ("popularity", "mean"), 
                               Total_Movies = ("Actors", "count"))

# %%
agg.nlargest(20,"Total_Movies")
# Out:
#                     Total_Revenue  Mean_Revenue  Mean_Rating   Mean_Pop  \
# Actors
# Bess Flowers           368.913259     14.756530     6.184186   2.030528
# Christopher Lee       9417.047887    324.725789     5.910204   4.749606
# John Wayne             236.094000     11.242571     5.712097   3.092939
# Samuel L. Jackson    17109.620672    213.870258     6.266116  11.703945
# Michael Caine         8053.404838    191.747734     6.269444   8.265272
# Gérard Depardieu      1247.608953     95.969919     6.053211   3.703836
# John Carradine         255.839586     19.679968     5.546667   2.434950
# Donald Sutherland     5390.766679    138.224787     6.233962   7.003230
# Jackie Chan           4699.185933    146.849560     6.275701   5.862638
# Frank Welker         13044.152470    326.103812     6.310377   9.571404
# Robert De Niro        5877.091223     81.626267     6.425000   8.714611
# Danny Trejo           2572.233447     73.492384     5.187129   5.738545
# ...

# %%
plt.figure(figsize = (12, 8))
agg.Total_Revenue.nlargest(10).plot(kind='bar', fontsize = 15)
plt.title("Total Revenue",fontsize = 20)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.show()

# %%
agg[agg.Total_Movies >= 10].nlargest(10, "Mean_Revenue")
# Out:
#                   Total_Revenue  Mean_Revenue  Mean_Rating   Mean_Pop  \
# Actors
# Gloria Stuart       1845.034188   1845.034188     6.368750   3.477432
# Keith Richards      2967.713802    989.237934     6.463636   5.032988
# Zoë Wanamaker        976.475550    976.475550     6.330000   6.819019
# James Cameron       1862.075059    931.037529     7.063636   4.691718
# Matthew Lewis       7915.312500    879.479167     7.372727  23.097479
# Luke de Woolfson    1720.671036    860.335518     5.718182   8.767206
# Yuri Lowenthal      1708.162716    854.081358     6.188235  19.884649
# Dominic Monaghan    3289.607607    822.401902     6.045455  10.621675
# Philip Ng            821.708551    821.708551     5.920000   6.353320
# Peter Mayhew        4820.721631    803.453605     6.700000  12.303552
#
#                   Total_Movies
# Actors
# Gloria Stuart               18
# Keith Richards              23
# Zoë Wanamaker               10
# James Cameron               12
# ...

# %%
agg[agg.Total_Movies >= 10].nlargest(10, "Mean_Rating")
# Out:
#                     Total_Revenue  Mean_Revenue  Mean_Rating   Mean_Pop  \
# Actors
# Masao Hayama             0.000000           NaN     8.840000   0.319471
# David Attenborough       0.000000           NaN     8.270000   2.147383
# Emil Jannings            0.000000           NaN     7.780000   1.700761
# Halit Akçatepe           0.214600      0.214600     7.780000   0.741727
# Yo Oizumi              511.210189    102.242038     7.723077   7.512642
# Şener Şen               11.074013      3.691338     7.693333   0.912166
# Ayşen Gruda              0.912800      0.456400     7.677778   0.743196
# Akira Tani               0.327081      0.163541     7.654545   5.041536
# Joseph Oliveira       3543.443905    354.344390     7.640000  34.449773
# Björk                   51.332532     25.666266     7.620000   2.362645
#
#                     Total_Movies
# Actors
# Masao Hayama                  10
# David Attenborough            11
# Emil Jannings                 10
# ...

# %%
agg[agg.Total_Movies >= 10].nlargest(10, "Mean_Pop")
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating   Mean_Pop  \
# Actors
# Katy Mixon         1519.572457    151.957246     5.841667  51.974337
# Terry Notary       6947.211370    694.721137     6.472727  51.575849
# Goran D. Kleut     2568.942448    366.991778     6.000000  42.322667
# Mark Smith         2195.523957    243.947106     6.545455  40.076962
# Jon Hamm           3449.345393    191.630300     6.328000  39.417351
# Gal Gadot          5449.532840    495.412076     6.327273  37.385856
# Ava Acres          6272.358330    482.489102     5.985714  36.260864
# Emma Watson        9639.203121    535.511284     6.768421  35.965301
# Joseph Oliveira    3543.443905    354.344390     7.640000  34.449773
# Keith Jardine      1062.491947    212.498389     5.963636  32.003903
#
#                  Total_Movies
# Actors
# Katy Mixon                 12
# Terry Notary               11
# Goran D. Kleut             10
# Mark Smith                 11
# Jon Hamm                   25
# ...

# %% [markdown]
# ## Most Successful Genres

# %%
movies.release_date.dropna(inplace=True)

# %%
movies['year'] = movies.release_date.apply(lambda x:x.year)

# %%
movies.genres.dropna(inplace=True)

# %%
genres = movies.genres.str.split('|',expand=True)

# %%
genres = genres.stack().reset_index(level=1,drop=True).to_frame()

# %%
genres.columns = ['genre']

# %%
genres = genres.merge(movies[['title','budget_musd','revenue_musd','vote_count','vote_average','popularity','year','profit','ROI']],how='left',left_index=True,right_index=True)

# %%
genres
# Out:
#           genre                             title  budget_musd  revenue_musd  \
# id
# 2         Drama                             Ariel          NaN           NaN
# 2         Crime                             Ariel          NaN           NaN
# 3         Drama               Shadows in Paradise          NaN           NaN
# 3        Comedy               Shadows in Paradise          NaN           NaN
# 5         Crime                        Four Rooms      4.00000           4.3
# ...         ...                               ...          ...           ...
# 468343  Romance          Silja - nuorena nukkunut          NaN           NaN
# 468707  Romance  Thick Lashes of Lauri Mäntyvaara      1.25404           NaN
# 468707   Comedy  Thick Lashes of Lauri Mäntyvaara      1.25404           NaN
# 469172  Fantasy   Manuel on the Island of Wonders          NaN           NaN
# 469172    Drama   Manuel on the Island of Wonders          NaN           NaN
#
# ...

# %%
agg = genres.groupby('genre').agg({'budget_musd':['sum','mean'],'revenue_musd':['sum','mean'],'title':'count','vote_count':'count','vote_average':'mean','popularity':'mean'})

# %%
agg.nlargest(20,('budget_musd','sum'))
#Genres with most allocated budgets
# Out:
#                   budget_musd              revenue_musd              title  \
#                           sum       mean            sum        mean  count
# genre
# Action           77688.077617  36.766719  201388.050019  116.073804   6542
# Drama            70013.580668  16.878877  160754.363574   43.826162  20054
# Adventure        65705.926364  51.093255  199978.669360  179.192356   3468
# Comedy           60095.553370  21.601565  166845.045970   64.097213  13067
# Thriller         55504.980272  23.370518  129724.552970   69.520125   7565
# Science Fiction  35344.229130  35.450581   97847.960421  131.516076   3013
# Fantasy          34256.683311  46.991335  103920.152145  166.006633   2290
# Family           33519.899995  46.620167  107076.778493  159.103683   2740
# Crime            27601.759972  21.958441   63375.730411   58.518680   4282
# Romance          26034.954973  17.484859   73473.190426   51.272289   6662
# ...

# %%
agg.nlargest(20,('revenue_musd','sum'))
#Genres generating most revenue
# Out:
#                   budget_musd              revenue_musd              title  \
#                           sum       mean            sum        mean  count
# genre
# Action           77688.077617  36.766719  201388.050019  116.073804   6542
# Adventure        65705.926364  51.093255  199978.669360  179.192356   3468
# Comedy           60095.553370  21.601565  166845.045970   64.097213  13067
# Drama            70013.580668  16.878877  160754.363574   43.826162  20054
# Thriller         55504.980272  23.370518  129724.552970   69.520125   7565
# Family           33519.899995  46.620167  107076.778493  159.103683   2740
# Fantasy          34256.683311  46.991335  103920.152145  166.006633   2290
# Science Fiction  35344.229130  35.450581   97847.960421  131.516076   3013
# Romance          26034.954973  17.484859   73473.190426   51.272289   6662
# Animation        19957.486079  46.738843   67432.971320  176.989426   1911
# ...

# %%
agg.nlargest(20,('title','count'))
#Genre-wise number of movies
# Out:
#                   budget_musd              revenue_musd              title  \
#                           sum       mean            sum        mean  count
# genre
# Drama            70013.580668  16.878877  160754.363574   43.826162  20054
# Comedy           60095.553370  21.601565  166845.045970   64.097213  13067
# Thriller         55504.980272  23.370518  129724.552970   69.520125   7565
# Romance          26034.954973  17.484859   73473.190426   51.272289   6662
# Action           77688.077617  36.766719  201388.050019  116.073804   6542
# Horror           11820.161791   9.336621   30837.094673   41.955231   4634
# Crime            27601.759972  21.958441   63375.730411   58.518680   4282
# Documentary        464.143783   1.894464    1449.112153    6.647303   3867
# Adventure        65705.926364  51.093255  199978.669360  179.192356   3468
# Science Fiction  35344.229130  35.450581   97847.960421  131.516076   3013
# ...
